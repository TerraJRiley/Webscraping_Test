# %%
import numpy as np
import pandas as pd

# %%
df_scraped.to_csv("../Webscrape_Data/scraped_data.csv", index = False)

print(df_scraped.shape)
df_scraped.tail()
# Out:
# (369, 230)
#           Url_Key                               Profile Picture Link  \
# 364  1.000140e+14                                                NaN
# 365  1.000140e+14                                                NaN
# 366  1.846154e+09                                                NaN
# 367  1.846154e+09  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# 368  1.000242e+14                                                NaN
#
#                     Name  Num_Friends                      Intro 1  \
# 364  Scraper 0 has dibs!          NaN                          NaN
# 365        Scrape Failed          NaN                          NaN
# 366  Scraper 0 has dibs!          NaN                          NaN
# 367        Mike Cervera         316.0  Lives in San Antonio, Texas
# 368  Scraper 0 has dibs!          NaN                          NaN
#
#                      Intro 2 Intro 3               Intro 4 Intro 5  \
# 364                      NaN     NaN                   NaN     NaN
# 365                      NaN     NaN                   NaN     NaN
# 366                      NaN     NaN                   NaN     NaN
# 367  From San Antonio, Texas  Single  Followed by 1 person     NaN
# 368                      NaN     NaN                   NaN     NaN
#
#                                       Overview (About)  ...  \
# 364                                                NaN  ...
# 365                                                NaN  ...
# 366                                                NaN  ...
# 367  rolloff driver at Republic service of San Anto...  ...
# 368                                                NaN  ...
#
#     Details About Tina Details About Layton Details About Minga  \
# 364                NaN                  NaN                 NaN
# 365                NaN                  NaN                 NaN
# 366                NaN                  NaN                 NaN
# 367                NaN                  NaN                 NaN
# 368                NaN                  NaN                 NaN
#
#     Details About Presley Details About Martin Details About Genevieve  \
# 364                   NaN                  NaN                     NaN
# 365                   NaN                  NaN                     NaN
# 366                   NaN                  NaN                     NaN
# 367                   NaN                  NaN                     NaN
# 368                   NaN                  NaN                     NaN
#
#     Details About Zoe Details About Optic Details About Hugo Eloy  \
# 364               NaN                 NaN                     NaN
# 365               NaN                 NaN                     NaN
# 366               NaN                 NaN                     NaN
# 367               NaN                 NaN                     NaN
# 368               NaN                 NaN                     NaN
#
#                                     Details About Mike
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367  About Mike\nNo additional details to show\nNam...
# 368                                                NaN
#
# [5 rows x 230 columns]

# %% [markdown]
# ## The Actual Cleaning Process

# %%
df_cleaned = df_scraped[~df_scraped['Name'].str.startswith("Scrape")]

# %%
# List of column names to merge
column_names_to_merge = [col for col in df_cleaned.columns if col.startswith('Details About ')]

# Merging the specified columns into one
df_cleaned['Details About Profile (About)'] = df_cleaned[column_names_to_merge].apply(
    lambda row: ' '.join(row.values.astype(str)).replace("nan", "").strip(" "), axis=1)

# Optionally, drop the original 'Column_' columns
df_cleaned = df_cleaned.drop(column_names_to_merge, axis=1)

# %%
df_cleaned["First Name"] = df_cleaned["Name"].map(lambda x: x.split(" ")[0])

# %%
df_cleaned["Last Name"] = df_cleaned["Name"].map(lambda x: x.strip(" ").split(" ")[-1])

# %%
df_cleaned = df_cleaned.rename({
    "Work and education"       : "Work & Education (About)",
    "Places lived"             : "Places Lived (About)",
    "Contact and basic info"   : "Contact and basic info (About)",
    "Family and relationships" :"Family & Relationships (About)",
    "Life events"              : "Life Events (About)"}, axis = 1)
# Out:
#              Url_Key                               Profile Picture Link  \
# 0          596897507  https://scontent-sjc3-1.xx.fbcdn.net/v/t39.308...
# 2         1456394131  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.1816...
# 3    100016005185942  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# 4    100009325868432  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# 6         1332364398  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# ..               ...                                                ...
# 583        528897913  https://scontent-sjc3-1.xx.fbcdn.net/v/t39.308...
# 587       1293337805  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.1816...
# 591  100022936776921  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.3049...
# 595       1835068298  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# 608       1497157945  https://scontent-sjc3-1.xx.fbcdn.net/v/t39.308...
#
#                                    Name  Num_Friends  \
# 0                         Sarah Murphy         444.0
# 2                 Alida Colborn Canion          92.0
# 3    Austin Anthony Duerr  (Texas Tony)        170.0
# 4                         George Gomez         688.0
# 6                          Maria Garza         105.0
# ..                                  ...          ...
# 583                Claudia Ma. Laporta         374.0
# 587                     Roger Buchhorn         238.0
# 591                      Rodolfo Reyes          24.0
# 595                   Benjamin Stanush         961.0
# 608                 Angela Hogan Brown         192.0
#
#                                                Intro 1  \
# 0                          Went to Ashland High School
# 2                                       Worked at USAA
# 3                                  Tow Operator at AAA
# 4             Went to Lanier High School (San Antonio)
# 6    Studied Accountancy at Lincoln School of Commerce
# ..                                                 ...
# 583                  Went to Instituto Rudyard Kipling
# 587               CFO at Drash Contracting Company LLC
# 591                                                NaN
# 595  Electrical manager at Diamondback Electrical S...
# 608  Studied Business Admin w/specialization in Per...
#
#                                                Intro 2  \
# 0                          Lives in San Antonio, Texas
# 2                                      Studied at UTSA
# 3                        Valet Attendant at Towne Park
# 4                          Lives in San Antonio, Texas
# 6                Went to Lincoln Northeast High School
# ..                                                 ...
# 583                                                NaN
# 587   Studied Accountancy at Texas Lutheran University
# 591                                                NaN
# 595  Studies Construction Business Management at Ro...
# 608                  Went to Blessed Sacrament Academy
#
#                                   Intro 3                        Intro 4  \
# 0                 From San Antonio, Texas         Married to Matt Murphy
# 2           Went to Roosevelt High School                            NaN
# 3             Former Delivery at DoorDash          Went to La Vernia ISD
# 4                 From San Antonio, Texas                         Single
# 6                                 Married                            NaN
# ..                                    ...                            ...
# 583                                   NaN                            NaN
# 587  Went to Victoria Stroman High School    Married to Beverly Buchhorn
# 591                                   NaN                            NaN
# 595                 Went to La Vernia ISD  Lives in New Braunfels, Texas
# 608           Lives in San Antonio, Texas        From San Antonio, Texas
#
#                       Intro 5  \
# 0         Joined October 2007
# 2                         NaN
# 3    Lives in Somerset, Texas
# 4                         NaN
# 6                         NaN
# ..                        ...
# 583                       NaN
# 587                       NaN
# 591                       NaN
# 595     From La Vernia, Texas
# 608                  Divorced
#
#                                       Overview (About)  ...  \
# 0    No workplaces to show\nWent to Ashland High Sc...  ...
# 2    Worked at USAA\nStudied at UTSA\nGraduated in ...  ...
# 3    Tow Operator at AAA and Valet Attendant at Tow...  ...
# 4    No workplaces to show\nWent to Lanier High Sch...  ...
# 6    No workplaces to show\nStudied Accountancy at ...  ...
# ..                                                 ...  ...
# 583  No workplaces to show\nWent to Instituto Rudya...  ...
# 587  CFO at Drash Contracting Company LLC\nMay 2013...  ...
# 591  No workplaces to show\nNo schools to show\nNo ...  ...
# 595  Electrical manager at Diamondback Electrical S...  ...
# 608  No workplaces to show\nStudied Business Admin ...  ...
#
#                                         Intro 7            Intro 8  \
# 0                                           NaN                NaN
# 2                                           NaN                NaN
# 3    Pronounces name AWS-ten AN-thuh-nee DOO-er  Joined March 2017
# 4                                           NaN                NaN
# 6                                           NaN                NaN
# ..                                          ...                ...
# 583                                         NaN                NaN
# 587                                         NaN                NaN
# 591                                         NaN                NaN
# 595                            Joined June 2009                NaN
# 608                                         NaN                NaN
#
#     Privacy and legal info Profile transparency Intro 9 Intro 10 Intro 11  \
# 0                      NaN                  NaN     NaN      NaN      NaN
# 2                      NaN                  NaN     NaN      NaN      NaN
# 3                      NaN                  NaN     NaN      NaN      NaN
# 4                      NaN                  NaN     NaN      NaN      NaN
# 6                      NaN                  NaN     NaN      NaN      NaN
# ..                     ...                  ...     ...      ...      ...
# 583                    NaN                  NaN     NaN      NaN      NaN
# 587                    NaN                  NaN     NaN      NaN      NaN
# 591                    NaN                  NaN     NaN      NaN      NaN
# 595                    NaN                  NaN     NaN      NaN      NaN
# 608                    NaN                  NaN     NaN      NaN      NaN
#
#                          Details About Profile (About) First Name Last Name
# 0    Relationship\nMatt Murphy\nMarried to Matt Mur...      Sarah    Murphy
# 2    About Alida\nNo additional details to show\nNa...      Alida    Canion
# 3    About Austin\nNo additional details to show\nN...     Austin     Tony)
# 4    About George\nNo additional details to show\nN...     George     Gomez
# 6    About Maria\nNo additional details to show\nNa...      Maria     Garza
# ..                                                 ...        ...       ...
# 583  About Claudia\nNo additional details to show\n...    Claudia   Laporta
# 587  Relationship\nBeverly Buchhorn\nMarried to Bev...      Roger  Buchhorn
# 591  Relationship\nNo relationship info to show\nFa...    Rodolfo     Reyes
# 595  About Benjamin\nI'm a Journeymen Electrician. ...   Benjamin   Stanush
# 608  Relationship\nDivorced\nFamily members\nCassid...     Angela     Brown
#
# [132 rows x 26 columns]

# %%
df_cleaned("../Webscrape_Data/Terra_Riley_Facebook_Test_Final.csv", index = False)

# %% [markdown]
# # Code Recycling

# %% [markdown]
# df_sample = pd.read_csv("./data/sample_edited.txt", sep=":", header=None,
#                         names=["Other_Number", "Url_Key", "Name_First", "Name_Last", "Gender",
#                                "1","2","3","4","5","6","7","8","9"])

# %% [markdown]
# df_scraped = pd.read_csv('./data/scraped_data.csv')

# %% [markdown]
# df_sample = pd.read_csv("../Webscrape_Data/sample_edited.txt", sep=":", header=None,
#                         names=["Other_Number", "Url_Key", "Name_First", "Name_Last", "Gender",
#                                "1","2","3","4","5","6","7","8","9"])

# %%
pd.read_csv("../Webscrape_Data/scraped_data.csv")
# Out:
#           Url_Key                               Profile Picture Link  \
# 0    5.968975e+08  https://scontent-sjc3-1.xx.fbcdn.net/v/t39.308...
# 1    1.000284e+14                                                NaN
# 2    1.456394e+09  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.1816...
# 3    1.000160e+14  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# 4    1.000093e+14  https://scontent-sjc3-1.xx.fbcdn.net/v/t1.6435...
# ..            ...                                                ...
# 373  1.000014e+14                                                NaN
# 374  1.000014e+14                                                NaN
# 375  1.000145e+14                                                NaN
# 376  1.000145e+14                                                NaN
# 377  1.000125e+14                                                NaN
#
#                                    Name  Num_Friends  \
# 0                         Sarah Murphy         444.0
# 1                         Scrape Failed          NaN
# 2                 Alida Colborn Canion          92.0
# 3    Austin Anthony Duerr  (Texas Tony)        170.0
# 4                         George Gomez         688.0
# ..                                  ...          ...
# 373             Scraper Copy2 has dibs!          NaN
# 374                       Scrape Failed          NaN
# 375             Scraper Copy2 has dibs!          NaN
# 376                       Scrape Failed          NaN
# 377             Scraper Copy2 has dibs!          NaN
#
#                                       Intro 1                        Intro 2  \
# 0                 Went to Ashland High School    Lives in San Antonio, Texas
# 1                                         NaN                            NaN
# 2                              Worked at USAA                Studied at UTSA
# 3                         Tow Operator at AAA  Valet Attendant at Towne Park
# 4    Went to Lanier High School (San Antonio)    Lives in San Antonio, Texas
# ..                                        ...                            ...
# 373                                       NaN                            NaN
# 374                                       NaN                            NaN
# 375                                       NaN                            NaN
# 376                                       NaN                            NaN
# 377                                       NaN                            NaN
#
#                            Intro 3                 Intro 4  \
# 0          From San Antonio, Texas  Married to Matt Murphy
# 1                              NaN                     NaN
# 2    Went to Roosevelt High School                     NaN
# 3      Former Delivery at DoorDash   Went to La Vernia ISD
# 4          From San Antonio, Texas                  Single
# ..                             ...                     ...
# 373                            NaN                     NaN
# 374                            NaN                     NaN
# 375                            NaN                     NaN
# 376                            NaN                     NaN
# 377                            NaN                     NaN
#
#                       Intro 5  \
# 0         Joined October 2007
# 1                         NaN
# 2                         NaN
# 3    Lives in Somerset, Texas
# 4                         NaN
# ..                        ...
# 373                       NaN
# 374                       NaN
# 375                       NaN
# 376                       NaN
# 377                       NaN
#
#                                       Overview (About)  ...  \
# 0    No workplaces to show\nWent to Ashland High Sc...  ...
# 1                                                  NaN  ...
# 2    Worked at USAA\nStudied at UTSA\nGraduated in ...  ...
# 3    Tow Operator at AAA and Valet Attendant at Tow...  ...
# 4    No workplaces to show\nWent to Lanier High Sch...  ...
# ..                                                 ...  ...
# 373                                                NaN  ...
# 374                                                NaN  ...
# 375                                                NaN  ...
# 376                                                NaN  ...
# 377                                                NaN  ...
#
#     Details About Layton Details About Minga Details About Presley  \
# 0                    NaN                 NaN                   NaN
# 1                    NaN                 NaN                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    NaN                 NaN                   NaN
# ..                   ...                 ...                   ...
# 373                  NaN                 NaN                   NaN
# 374                  NaN                 NaN                   NaN
# 375                  NaN                 NaN                   NaN
# 376                  NaN                 NaN                   NaN
# 377                  NaN                 NaN                   NaN
#
#     Details About Martin Details About Genevieve Details About Zoe  \
# 0                    NaN                     NaN               NaN
# 1                    NaN                     NaN               NaN
# 2                    NaN                     NaN               NaN
# 3                    NaN                     NaN               NaN
# 4                    NaN                     NaN               NaN
# ..                   ...                     ...               ...
# 373                  NaN                     NaN               NaN
# 374                  NaN                     NaN               NaN
# 375                  NaN                     NaN               NaN
# 376                  NaN                     NaN               NaN
# 377                  NaN                     NaN               NaN
#
#     Details About Optic Details About Hugo Eloy Details About Mike  \
# 0                   NaN                     NaN                NaN
# 1                   NaN                     NaN                NaN
# 2                   NaN                     NaN                NaN
# 3                   NaN                     NaN                NaN
# 4                   NaN                     NaN                NaN
# ..                  ...                     ...                ...
# 373                 NaN                     NaN                NaN
# 374                 NaN                     NaN                NaN
# 375                 NaN                     NaN                NaN
# 376                 NaN                     NaN                NaN
# 377                 NaN                     NaN                NaN
#
#     Details About Laura
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 373                 NaN
# 374                 NaN
# 375                 NaN
# 376                 NaN
# 377                 NaN
#
# [378 rows x 231 columns]
